# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly as py
py.tools.set_credentials_file(username='beench', api_key='yKNogmZMFUgUU57hdK6L')
import plotly.graph_objs as go

# %%
df = pd.read_csv('./data/Project 2 sample (93).csv', header=None)

# %%
df
# Out:
#               0             1             2             3             4   \
# 0   3.200650e-09  5.620680e-09  9.838810e-09  1.715330e-08  2.975520e-08
# 1   3.210560e-09  5.641320e-09  9.882060e-09  1.724430e-08  2.994700e-08
# 2   3.220340e-09  5.661670e-09  9.924690e-09  1.733390e-08  3.013610e-08
# 3   3.229990e-09  5.681730e-09  9.966690e-09  1.742230e-08  3.032240e-08
# 4   3.239490e-09  5.701490e-09  1.000800e-08  1.750930e-08  3.050600e-08
# 5   3.248860e-09  5.720940e-09  1.004870e-08  1.759490e-08  3.068660e-08
# 6   3.258080e-09  5.740080e-09  1.008880e-08  1.767910e-08  3.086420e-08
# 7   3.267160e-09  5.758910e-09  1.012810e-08  1.776180e-08  3.103880e-08
# 8   3.276090e-09  5.777410e-09  1.016680e-08  1.784300e-08  3.121010e-08
# 9   3.284870e-09  5.795590e-09  1.020470e-08  1.792260e-08  3.137820e-08
# 10  3.293500e-09  5.813430e-09  1.024190e-08  1.800070e-08  3.154300e-08
# 11  3.301980e-09  5.830940e-09  1.027830e-08  1.807720e-08  3.170430e-08
# ...

# %%
test = np.asarray(df)

# %%
data = [go.Contour(
    z = test, 
    colorscale='Jet'
)]
fig = go.Figure(data = data)
py.plotly.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~beench/16.embed" height="525px" width="100%"></iframe>
